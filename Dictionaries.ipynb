# %%
import pandas as pd
pd.read_csv('nba.csv')
# Out:
#        Unnamed: 0    Year             Player  Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  G-F  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker   SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst   SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels    F  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels    F  24.0  DNN  13.0   NaN
# ...           ...     ...                ...  ...   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller   PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller    C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman    C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser   SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac    C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB    AST   STL   BLK   TOV  \
# ...

# %% [markdown]
# # One entry

# %%
my_dictionary = {'name':['sammy'],'gender':['male'],'favorite_color':['green']}
pd.DataFrame.from_dict(my_dictionary)
# Out:
#     name gender favorite_color
# 0  sammy   male          green

# %% [markdown]
# # Multiple Entries

# %%
my_dictionary = {'name':['sammy','alex','richard','katie'],'gender':['male','male','male','female'],'favorite_color':['green','blue','red','blue']}
pd.DataFrame.from_dict(my_dictionary)
# Out:
#       name  gender favorite_color
# 0    sammy    male          green
# 1     alex    male           blue
# 2  richard    male            red
# 3    katie  female           blue

# %% [markdown]
# # .keys(), .values(), .items()

# %%
my_dictionary.keys()
my_dictionary.values()
my_dictionary.items()
# Out:
# dict_items([('name', ['sammy', 'alex', 'richard', 'katie']), ('gender', ['male', 'male', 'male', 'female']), ('favorite_color', ['green', 'blue', 'red', 'blue'])])

# %% [markdown]
# # Adding a new key

# %%
my_dictionary
# Out:
# {'name': ['sammy', 'alex', 'richard', 'katie'],
#  'gender': ['male', 'male', 'male', 'female'],
#  'favorite_color': ['green', 'blue', 'red', 'blue']}

# %%
my_dictionary['subject'] = ['statistics', 'astrology', 'english', 'biology']

# %%
my_dictionary
# Out:
# {'name': ['sammy', 'alex', 'richard', 'katie'],
#  'gender': ['male', 'male', 'male', 'female'],
#  'favorite_color': ['green', 'blue', 'red', 'blue'],
#  'subject': ['statistics', 'astrology', 'english', 'biology']}

# %%
pd.DataFrame.from_dict(my_dictionary)
# Out:
#       name  gender favorite_color     subject
# 0    sammy    male          green  statistics
# 1     alex    male           blue   astrology
# 2  richard    male            red     english
# 3    katie  female           blue     biology

# %%
my_dictionary['hometown'] = ['Chicago', 'NYC', 'Houston']

# %%
my_dictionary
# Out:
# {'name': ['sammy', 'alex', 'richard', 'katie'],
#  'gender': ['male', 'male', 'male', 'female'],
#  'favorite_color': ['green', 'blue', 'red', 'blue'],
#  'subject': ['statistics', 'astrology', 'english', 'biology'],
#  'hometown': ['Chicago', 'NYC', 'Houston']}
