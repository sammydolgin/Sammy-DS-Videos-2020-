# %%
import pandas as pd
df = pd.read_csv('nba.csv')

# %%
df = df.drop(['PTS','PF','Tm','Player'],1)

# %%
df.head()
# Out:
#    Unnamed: 0    Year  Pos   Age     G  GS  MP  PER    TS%  3PAr  ...     FT  \
# 0           0  1950.0  G-F  31.0  63.0 NaN NaN  NaN  0.368   NaN  ...  170.0
# 1           1  1950.0   SG  29.0  49.0 NaN NaN  NaN  0.435   NaN  ...   75.0
# 2           2  1950.0   SF  25.0  67.0 NaN NaN  NaN  0.394   NaN  ...   90.0
# 3           3  1950.0    F  24.0  15.0 NaN NaN  NaN  0.312   NaN  ...   19.0
# 4           4  1950.0    F  24.0  13.0 NaN NaN  NaN  0.308   NaN  ...   17.0
#
#      FTA    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV
# 0  241.0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN
# 1  106.0  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN
# 2  129.0  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN
# 3   34.0  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN
# 4   31.0  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN
#
# [5 rows x 49 columns]

# %%
df = df.drop(50,0)

# %%
df.iloc[1707]
# Out:
# Unnamed: 0           1712
# Year                 1962
# Player        Archie Dees
# Pos                   F-C
# Age                    25
# Tm                    TOT
# G                      21
# GS                    NaN
# MP                    288
# PER                   NaN
# TS%                 0.507
# 3PAr                  NaN
# FTr                   0.4
# ORB%                  NaN
# DRB%                  NaN
# TRB%                  NaN
# AST%                  NaN
# STL%                  NaN
# BLK%                  NaN
# TOV%                  NaN
# USG%                  NaN
# blanl                 NaN
# OWS                   NaN
# DWS                   NaN
# WS                    NaN
# WS/48                 NaN
# blank2                NaN
# OBPM                  NaN
# DBPM                  NaN
# BPM                   NaN
# VORP                  NaN
# FG                     51
# FGA                   115
# FG%                 0.443
# 3P                    NaN
# ...
