# %% [markdown]
# # Lists

# %% [markdown]
# # Connection To Data

# %%
import pandas
list(pd.read_csv('nba.csv').Player)
# Out:
# ['Curly Armstrong',
#  'Cliff Barker',
#  'Leo Barnhorst',
#  'Ed Bartels',
#  'Ed Bartels',
#  'Ed Bartels',
#  'Ralph Beard',
#  'Gene Berce',
#  'Charlie Black',
#  'Charlie Black',
#  'Charlie Black',
#  'Nelson Bobb',
#  'Jake Bornheimer',
#  'Vince Boryla',
#  'Don Boven',
#  'Harry Boykoff',
#  'Joe Bradley',
#  'Bob Brannum',
#  'Carl Braun',
#  'Frankie Brian',
#  'Price Brookfield',
#  'Bob Brown',
#  'Jim Browne',
#  'Walt Budko',
#  'Jack Burmaster',
#  'Tommy Byrnes',
#  'Bill Calhoun',
#  'Don Carlson',
#  'Bob Carpenter',
#  'Jake Carter',
#  'Jake Carter',
#  'Jake Carter',
#  'Al Cervi*',
#  'John Chaney',
#  'John Chaney',
#  'John Chaney',
#  'Leroy Chollet',
#  'Bill Closs',
#  'Paul Cloyd',
#  'Paul Cloyd',
#  'Paul Cloyd',
#  'Jack Coleman',
#  'Bobby Cook',
#  'Ray Corley',
#  'Jack Cotton',
#  'Dillard Crocker',
#  'Chink Crossin',
#  'Fran Curran',
#  'Jimmy Darden',
#  'Bob Davies*',
#  'Hook Dillon',
#  'Earl Dodd',
#  'Joe Dolhon',
#  'Bob Doll',
# ...

# %% [markdown]
# # Connection To Strings

# %%
x = sammy
x[0]

y = [3,4,5,8]
y[0]
y[1:]

# %% [markdown]
# # Appending and mutability

# %%
y = [3,4,5]

# %%
#append IS mutating

y.append('Y')
y
# Out:
# [3, 4, 5, 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y']

# %%
x = 3

# %%
#addition is non-mutating
x = x+1
x
# Out:
# 17

# %% [markdown]
# # Inserting

# %%
#insert is a mutating function

y
y.insert('Z',6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-568457f7a1ee> in <module>
#       2
#       3 y
# ----> 4 y.insert('Z',6)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
y
# Out:
# [3,
#  4,
#  5,
#  'Y',
#  'Y',
#  'Y',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Z',
#  'Y',
#  'Y',
#  'Y',
#  'Y',
#  'Y',
#  'Y',
#  'Y']

# %% [markdown]
# # Sorting

# %%
#sorted is NOT a mutating function

a = ['d','a','3','apple','54','banana','aardvark']
sorted(a)
# Out:
# ['3', '54', 'a', 'aardvark', 'apple', 'banana', 'd']

# %%
a
# Out:
# [5, 2, 9, 77, 63, 10]

# %% [markdown]
# # Lambda Manipulation

# %%
def function(x):
    return x+1

function(3)
# Out:
# 4

# %%
a = [2,6,89]
list(map(lambda x: x+1, a))
# Out:
# [3, 7, 90]

# %%
x = [2,3,4,5,6,7,8]
list(map(lambda z: z**2, x))
# Out:
# [4, 9, 16, 25, 36, 49, 64]
